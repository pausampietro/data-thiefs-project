# %%
import requests as re
import json
import pandas as pd

# %%
response = re.get("http://aviation-edge.com/v2/public/flights?key=8bbf2c-a12972&depIata=BCN")
response.headers
# Out:
# {'Date': 'Sun, 17 Mar 2019 11:46:59 GMT', 'Server': 'Apache', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'X-Requested-With, Content-Type, Accept, Origin, Authorization', 'Access-Control-Allow-Methods': 'GET, POST, PUT, DELETE, OPTIONS', 'Cache-Control': 'max-age=172800', 'Expires': 'Tue, 19 Mar 2019 11:46:59 GMT', 'Vary': 'Accept-Encoding,User-Agent', 'Content-Encoding': 'gzip', 'Content-Length': '9149', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}

# %%
flights = response.json()
print(json.dumps(flights,sort_keys=True, indent=4))
# Out:
# [
#     {
#         "aircraft": {
#             "iataCode": "B738",
#             "icao24": "4CA88E",
#             "icaoCode": "B738",
#             "regNumber": "EIENB"
#         },
#         "airline": {
#             "iataCode": "FR",
#             "icaoCode": "RYR"
#         },
#         "arrival": {
#             "iataCode": "XRY",
#             "icaoCode": "LEJR"
#         },
#         "departure": {
#             "iataCode": "BCN",
#             "icaoCode": "LEBL"
#         },
#         "flight": {
#             "iataNumber": "FR1283",
#             "icaoNumber": "RYR1283",
#             "number": "1283"
#         },
#         "geography": {
#             "altitude": 11277.6,
#             "direction": 250.9,
#             "latitude": 38.5703,
#             "longitude": -2.1254
#         },
#         "speed": {
#             "horizontal": 752.616,
#             "isGround": 0,
#             "vertical": 0
#         },
#         "status": "en-route",
#         "system": {
# ...

# %%
df = pd.DataFrame(flights)
df
# Out:
#                                               aircraft  \
# 0    {'regNumber': 'EIENB', 'icaoCode': 'B738', 'ic...
# 1    {'regNumber': 'TCLNB', 'icaoCode': 'A332', 'ic...
# 2    {'regNumber': 'B6533', 'icaoCode': 'A332', 'ic...
# 3    {'regNumber': 'GEZIM', 'icaoCode': 'A319', 'ic...
# 4    {'regNumber': 'GEZMK', 'icaoCode': 'A319', 'ic...
# 5    {'regNumber': 'ECMIR', 'icaoCode': 'A319', 'ic...
# 6    {'regNumber': 'ECLQM', 'icaoCode': 'A320', 'ic...
# 7    {'regNumber': 'ECLQM', 'icaoCode': 'A320', 'ic...
# 8    {'regNumber': 'ECLVO', 'icaoCode': 'A320', 'ic...
# 9    {'regNumber': 'ECMLE', 'icaoCode': 'A320', 'ic...
# 10   {'regNumber': 'ECMOY', 'icaoCode': 'A332', 'ic...
# 11   {'regNumber': 'ECMBY', 'icaoCode': 'A320', 'ic...
# 12   {'regNumber': 'ECLOC', 'icaoCode': 'A320', 'ic...
# 13   {'regNumber': 'ECMLD', 'icaoCode': 'A321', 'ic...
# 14   {'regNumber': 'YRBGH', 'icaoCode': 'B737', 'ic...
# 15   {'regNumber': 'GEUYP', 'icaoCode': 'A320', 'ic...
# ...

# %%
plane_iata = pd.Series([plane['aircraft']['iataCode'] for plane in flights])
plane_icao = pd.Series([plane['aircraft']['icaoCode'] for plane in flights])
dep_iata = pd.Series([plane['departure']['iataCode'] for plane in flights])
arr_iata = pd.Series([plane['arrival']['iataCode'] for plane in flights])
speeds = pd.Series([plane['speed']['horizontal'] for plane in flights])

# %%
ls = arr_iata[1]
